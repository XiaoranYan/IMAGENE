# %%
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import pandas as pd
import seaborn as sns
import theano.tensor as tt
from sklearn.model_selection import train_test_split

sns.set(style='white', palette='deep', color_codes=True)

# %matplotlib inline

block0 = pd.read_csv('/gpfs/projects/UITS/IUNI/IMAGENE/Phom_output/subFeaturesAll.csv')
data = block0[['AGE','EDU','GENDER','DX']]
data = data[np.isfinite(data['AGE'])]
data.DX.unique()
train, test = train_test_split(data, test_size=0.2, stratify=data.DX)
type(test)

# %%
# Number of training points
n = len(train)
X0 = train[['AGE']].values

# Number of testing points
m = len(test)
X = test[['AGE']].values

n = len(train)
Y0 = train[['DX']].values
Y = test[['DX']].values
# Separate data into positive and negative classes
Y[Y == 'MCI'] = 1
Y[Y == 'NC'] = 0
Y0[Y0 == 'MCI'] = 1
Y0[Y0 == 'NC'] = 0

fig, ax = plt.subplots(figsize=(14, 6));
ax.scatter(X0, np.ma.masked_where(Y0 == 0, Y0), color='b', label='Positive Observations');
ax.scatter(X0, np.ma.masked_where(Y0 == 1, Y0), color='r', label='Negative Observations');
ax.scatter(X, Y, color='g', label='Testing Points');
ax.legend(loc='lower right');
#ax.set_xlim(-0.1, 3.1);
#ax.set_ylim(-0.2, 1.2);

# %%
with pm.Model() as model:
    # Again, f_sample is just a dummy variable
    f_sample = pm.Flat('f_sample', shape=n)
    f_transform = pm.invlogit(f_sample)

    # Binomial likelihood
    
    y = pm.Binomial('y', observed=Y0, n=np.ones(n), p=f_transform, shape=n)

    # Interpolate function values using noiseless covariance matrix
    # Covariance kernel parameters
    l = pm.Gamma("l", alpha=2, beta=2)
    # informative, positive normal prior on the period
    eta = pm.HalfNormal("eta")
    cov = eta**2 * pm.gp.cov.ExpQuad(1, l)
    noise = 0.1

    cov = f_scale * pm.gp.cov.ExpQuad(1, lengthscale)
    K = cov(X0)
    K_s = cov(X0, X)
    K_noise = K + noise * np.eye(n)

    # Add very slight perturbation to the covariance matrix diagonal to improve numerical stability
    K_stable = K + 1e-12 * np.eye(n)

    L = tt.slinalg.cholesky(K_stable)
    f_pred = pm.Deterministic('f_pred', tt.dot(K_s.T, tt.slinalg.solve(L.T, tt.slinalg.solve(L, f_transform))))

    # Use elliptical slice sampling
    ess_step = pm.EllipticalSlice(vars=[f_sample], prior_cov=K_stable)
    trace = pm.sample(3000, start=model.test_point, progressbar=True, step=[ess_step], random_seed=1, njobs =20)

# %%
#np.full((len(test), 1), 0.5)
# number of data points
X0.values[:,None]
# Out:
# array([[89.],
#        [65.],
#        [77.],
#        [79.],
#        [73.],
#        [75.],
#        [63.],
#        [70.],
#        [66.],
#        [75.],
#        [68.],
#        [71.],
#        [56.],
#        [76.],
#        [80.],
#        [63.],
#        [84.],
#        [84.],
#        [86.],
#        [56.],
#        [72.],
#        [64.],
#        [81.],
#        [83.],
#        [80.],
#        [66.],
#        [70.],
#        [68.],
#        [65.],
#        [63.],
#        [66.],
#        [72.],
#        [83.],
#        [76.],
#        [51.],
#        [60.],
#        [80.],
#        [66.],
#        [71.],
#        [61.],
#        [74.],
#        [65.],
#        [76.],
#        [77.],
#        [67.],
#        [83.],
#        [74.],
#        [62.],
#        [66.],
#        [52.],
#        [77.],
#        [85.],
#        [80.],
#        [56.],
#        [69.],
#        [60.],
#        [76.],
#        [66.],
#        [71.],
#        [53.],
#        [81.],
#        [59.],
#        [72.],
#        [77.],
#        [62.],
#        [68.],
#        [62.],
#        [73.],
#        [61.],
#        [69.],
#        [70.],
#        [61.],
#        [84.],
#        [58.],
#        [83.],
#        [67.],
#        [84.],
#        [70.],
#        [64.],
#        [67.],
#        [73.],
#        [58.],
#        [67.],
#        [63.],
#        [53.],
#        [81.],
#        [70.],
#        [70.],
#        [71.],
#        [66.],
#        [68.],
#        [62.],
#        [71.],
#        [79.],
#        [72.],
#        [72.],
#        [68.],
#        [81.],
#        [74.],
#        [67.],
#        [79.],
#        [78.],
#        [79.],
#        [70.],
#        [76.],
#        [67.],
#        [58.],
#        [76.],
#        [68.],
#        [60.],
#        [67.],
#        [56.],
#        [65.],
#        [71.],
#        [58.],
#        [73.],
#        [60.],
#        [57.],
#        [60.],
#        [61.],
#        [76.],
#        [77.],
#        [62.],
#        [64.]])

# %%
with pm.Model() as model:
    # covariance function
    l = pm.Gamma("l", alpha=2, beta=2)
    # informative, positive normal prior on the period
    eta = pm.HalfNormal("eta")
    cov = eta**2 * pm.gp.cov.ExpQuad(1, l)

    gp = pm.gp.Latent(cov_func=cov)

    # make gp prior
    f = gp.prior("f", X=X0)

    # logit link and Bernoulli likelihood
    p = pm.Deterministic("p", pm.math.invlogit(f))
    y_ = pm.Bernoulli("y", p=p, observed=Y0)

    trace = pm.sample(1000, progressbar=False, njobs =20)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (100 chains in 100 jobs)
# NUTS: [f_rotated_, eta, l]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, use_mmap, **kwargs)
#     989                 with sampler:
# --> 990                     for draw in sampler:
#     991                         trace = traces[draw.chain - chain]
#
# ~/.local/lib/python3.6/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     344         while self._active:
# --> 345             draw = ProcessAdapter.recv_draw(self._active)
#     346             proc, is_last, draw, tuning, stats, warns = draw
#
# ~/.local/lib/python3.6/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     235         pipes = [proc._msg_pipe for proc in processes]
# --> 236         ready = multiprocessing.connection.wait(pipes)
#     237         if not ready:
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/selectors.py in select(self, timeout)
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, use_mmap, **kwargs)
#     999                             if draw.warnings is not None:
# -> 1000                                 trace._add_warnings(draw.warnings)
#    1001             except ps.ParallelSamplingError as error:
#
# ~/.local/lib/python3.6/site-packages/pymc3/parallel_sampling.py in __exit__(self, *args)
#     372     def __exit__(self, *args):
# --> 373         ProcessAdapter.terminate_all(self._samplers)
#     374         if self._progress is not None:
#
# ~/.local/lib/python3.6/site-packages/pymc3/parallel_sampling.py in terminate_all(processes, patience)
#     270                     raise multiprocessing.TimeoutError()
# --> 271                 process.join(timeout)
#     272         except multiprocessing.TimeoutError:
#
# ~/.local/lib/python3.6/site-packages/pymc3/parallel_sampling.py in join(self, timeout)
#     225     def join(self, timeout=None):
# --> 226         self._process.join(timeout)
#     227
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/multiprocessing/process.py in join(self, timeout)
#     123         assert self._popen is not None, 'can only join a started process'
# --> 124         res = self._popen.wait(timeout)
#     125         if res is not None:
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/multiprocessing/popen_fork.py in wait(self, timeout)
#      46                 from multiprocessing.connection import wait
# ---> 47                 if not wait([self.sentinel], timeout):
#      48                     return None
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#
# /N/soft/rhel6/python/3.6.8/lib/python3.6/selectors.py in select(self, timeout)
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-dfb6f3d0e4ba> in <module>
#      15     y_ = pm.Bernoulli("y", p=p, observed=Y0)
#      16
# ---> 17     trace = pm.sample(1000, progressbar=False, njobs =100)
#
# ~/.local/lib/python3.6/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, nuts_kwargs, step_kwargs, progressbar, model, random_seed, live_plot, discard_tuned_samples, live_plot_kwargs, compute_convergence_checks, use_mmap, **kwargs)
#     437             _print_step_hierarchy(step)
#     438             try:
# --> 439                 trace = _mp_sample(**sample_args)
#     440             except pickle.PickleError:
#     441                 _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/.local/lib/python3.6/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, use_mmap, **kwargs)
#    1010             return MultiTrace(traces)
#    1011         except KeyboardInterrupt:
# -> 1012             traces, length = _choose_chains(traces, tune)
#    1013             return MultiTrace(traces)[:length]
#    1014         finally:
#
# ~/.local/lib/python3.6/site-packages/pymc3/sampling.py in _choose_chains(traces, tune)
#    1043     lengths = [max(0, len(trace) - tune) for trace in traces]
#    1044     if not sum(lengths):
# -> 1045         raise ValueError('Not enough samples to build a trace.')
#    1046
#    1047     idxs = np.argsort(lengths)[::-1]
#
# ValueError: Not enough samples to build a trace.

# %%
fig, ax = plt.subplots(figsize=(14, 6));
for idx in np.random.randint(4000, 5000, 500):
    ax.plot(X, trace['f_pred'][idx],  alpha=0.04, color='navy')
ax.scatter(X0, f, s=40, color='k');
#ax.set_xlim(0, 3);
#ax.set_ylim(-0.1, 1.1);

# %%
import sys
np.random.seed(1)

# number of data points
n = 200

# x locations
x = np.linspace(0, 1.5, n)

# true covariance
l_true = 0.1
eta_true = 1.0
cov_func = eta_true**2 * pm.gp.cov.ExpQuad(1, l_true)
K = cov_func(x[:,None]).eval()

# zero mean function
mean = np.zeros(n)

# sample from the gp prior
f_true = np.random.multivariate_normal(mean, K + 1e-6 * np.eye(n), 1).flatten()

# link function
def invlogit(x, eps=sys.float_info.epsilon):
    return (1.0 + 2.0 * eps) / (1.0 + np.exp(-x)) + eps

y = pm.Bernoulli.dist(p=invlogit(f_true)).random()

# %%
fig = plt.figure(figsize=(12,5)); ax = fig.gca()
ax.plot(x, invlogit(f_true), 'dodgerblue', lw=3, label="True rate");
ax.plot(x, y + np.random.randn(n)*0.01, 'ko', ms=3, label="Observed data");
ax.set_xlabel("X"); ax.set_ylabel("y"); plt.legend();

# %%
with pm.Model() as model:
    # covariance function
    l = pm.Gamma("l", alpha=2, beta=2)
    # informative, positive normal prior on the period
    eta = pm.HalfNormal("eta")
    cov = eta**2 * pm.gp.cov.ExpQuad(1, l)

    gp = pm.gp.Latent(cov_func=cov)

    # make gp prior
    f = gp.prior("f", X=x[:,None])

    # logit link and Bernoulli likelihood
    p = pm.Deterministic("p", pm.math.invlogit(f))
    y_ = pm.Bernoulli("y", p=p, observed=y)

    trace = pm.sample(1000, chains=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /N/u/yan30/Karst/.local/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /N/u/yan30/Karst/.local/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Sequential sampling (1 chains in 1 job)
# NUTS: [f_rotated_, eta, l]
#
#   0%|          | 0/1500 [00:00<?, ?it/s]/N/u/yan30/Karst/.local/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
#
#   0%|          | 1/1500 [00:04<1:48:36,  4.35s/it]
#   0%|          | 3/1500 [00:05<1:18:38,  3.15s/it]
#   0%|          | 4/1500 [00:05<59:35,  2.39s/it]
#   0%|          | 5/1500 [00:06<46:05,  1.85s/it]
#   0%|          | 6/1500 [00:07<40:35,  1.63s/it]
#   0%|          | 7/1500 [00:08<35:08,  1.41s/it]
#   1%|          | 8/1500 [00:09<33:22,  1.34s/it]
#   1%|          | 9/1500 [00:10<27:23,  1.10s/it]
